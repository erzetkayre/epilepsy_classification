# %% [markdown]
# # CNN-LSTM Model Development for Binary Classification

# %% [markdown]
# ## Import Python's Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## Loading and Reshaping Data

# %%
data = np.load("../../../data/ukb_processed/train/ternary_classification_datas.npy")          # load datas
label = np.load("../../../data/ukb_processed/train/ternary_classification_labels.npy")   # load labels

x = data.reshape(data.shape[0], data.shape[1], 1)
y = label

print(f"Binary Classification Dataset: {x.shape}, Labels: {np.unique(y)}")
# Out:
# Binary Classification Dataset: (540, 4097, 1), Labels: [0 1 2]

# %% [markdown]
# ## Train Data using CNN-LSTM

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, LSTM
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (confusion_matrix, precision_score, recall_score, f1_score, 
                           accuracy_score, roc_auc_score, roc_curve)
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os
import json

# Create directories for results
os.makedirs('cv_results', exist_ok=True)
os.makedirs('cv_results/models', exist_ok=True)
os.makedirs('cv_results/training_logs', exist_ok=True)

# Initialize
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
fold_results = []
confusion_matrices = []
all_histories = []
all_roc_data = []
class_names = ['Class_0', 'Class_1', 'Class_2']

# Initialize lists for detailed training logs
training_logs = []
epoch_by_epoch_data = []

print("Starting 10-Fold Cross Validation for Ternary Classification...")
print("=" * 60)

for fold_no, (train_index, val_index) in enumerate(skf.split(x, y), 1):
    print(f"\n🔄 Processing Fold {fold_no}/10")
    
    # Split data
    X_train_fold, X_val_fold = x[train_index], x[val_index]
    y_train_fold, y_val_fold = y[train_index], y[val_index]
    
    # Convert to categorical (one-hot encoding for 3 classes)
    y_train_categorical = to_categorical(y_train_fold, num_classes=3)
    y_val_categorical = to_categorical(y_val_fold, num_classes=3)
    
    # Custom callback
    class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs={}):
            if((logs.get('val_accuracy') > 0.95) and (logs.get('accuracy') > 0.95)):
                print(f"\n✅ Target reached at epoch {epoch + 1}")
                self.model.stop_training = True
    
    # Build model - Same architecture, output for ternary classification
    model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.1),
        
        Conv1D(filters=128, kernel_size=5, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),
        
        LSTM(128, return_sequences=True),
        Dropout(0.3),
        LSTM(64),
        Dropout(0.3),
                
        Dense(3, activation='softmax')  # Ternary classification: 3 neurons with softmax
    ])
    
    # Categorical crossentropy for multi-class classification
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Train model
    start_time = time.time()
    history = model.fit(X_train_fold, y_train_categorical, 
                        epochs=20, batch_size=30, 
                        validation_data=(X_val_fold, y_val_categorical),
                        callbacks=[myCallback()], verbose=1)
    
    training_time = time.time() - start_time
    
    # Evaluate
    scores = model.evaluate(X_val_fold, y_val_categorical, verbose=0)
    val_loss, val_accuracy = scores
    
    # Predictions
    y_pred_proba = model.predict(X_val_fold, verbose=0)
    y_pred = np.argmax(y_pred_proba, axis=1)
    
    # Calculate metrics for multi-class
    precision_macro = precision_score(y_val_fold, y_pred, average='macro')
    recall_macro = recall_score(y_val_fold, y_pred, average='macro')
    f1_macro = f1_score(y_val_fold, y_pred, average='macro')
    
    precision_weighted = precision_score(y_val_fold, y_pred, average='weighted')
    recall_weighted = recall_score(y_val_fold, y_pred, average='weighted')
    f1_weighted = f1_score(y_val_fold, y_pred, average='weighted')
    
    # Per-class metrics
    precision_per_class = precision_score(y_val_fold, y_pred, average=None)
    recall_per_class = recall_score(y_val_fold, y_pred, average=None)
    f1_per_class = f1_score(y_val_fold, y_pred, average=None)
    
    # AUC for multi-class (One-vs-Rest)
    try:
        auc_macro = roc_auc_score(y_val_categorical, y_pred_proba, average='macro', multi_class='ovr')
        auc_weighted = roc_auc_score(y_val_categorical, y_pred_proba, average='weighted', multi_class='ovr')
        # Per-class AUC
        auc_per_class = roc_auc_score(y_val_categorical, y_pred_proba, average=None, multi_class='ovr')
    except:
        auc_macro = 0.0
        auc_weighted = 0.0
        auc_per_class = [0.0, 0.0, 0.0]
    
    # Confusion Matrix
    cm = confusion_matrix(y_val_fold, y_pred)
    
    # Class distribution in validation set
    class_counts = np.bincount(y_val_fold, minlength=3)
    
    # Store results
    fold_result = {
        'Fold': fold_no,
        'Val_Accuracy': val_accuracy,
        'Val_Loss': val_loss,
        
        # Macro averages
        'Precision_Macro': precision_macro,
        'Recall_Macro': recall_macro,
        'F1_Score_Macro': f1_macro,
        'AUC_Macro': auc_macro,
        
        # Weighted averages
        'Precision_Weighted': precision_weighted,
        'Recall_Weighted': recall_weighted,
        'F1_Score_Weighted': f1_weighted,
        'AUC_Weighted': auc_weighted,
        
        # Per-class metrics
        'Precision_Class_0': precision_per_class[0],
        'Precision_Class_1': precision_per_class[1],
        'Precision_Class_2': precision_per_class[2],
        'Recall_Class_0': recall_per_class[0],
        'Recall_Class_1': recall_per_class[1],
        'Recall_Class_2': recall_per_class[2],
        'F1_Class_0': f1_per_class[0],
        'F1_Class_1': f1_per_class[1],
        'F1_Class_2': f1_per_class[2],
        'AUC_Class_0': auc_per_class[0],
        'AUC_Class_1': auc_per_class[1],
        'AUC_Class_2': auc_per_class[2],
        
        # Class distribution
        'Class_0_Count': class_counts[0],
        'Class_1_Count': class_counts[1],
        'Class_2_Count': class_counts[2],
        
        'Training_Time': training_time,
        'Epochs_Trained': len(history.history['loss'])
    }
    
    fold_results.append(fold_result)
    confusion_matrices.append(cm)
    all_histories.append(history.history)
    
    # Store ROC data for each class
    roc_fold_data = {}
    for i in range(3):
        fpr, tpr, _ = roc_curve(y_val_categorical[:, i], y_pred_proba[:, i])
        roc_fold_data[f'class_{i}'] = {'fpr': fpr, 'tpr': tpr, 'auc': auc_per_class[i]}
    all_roc_data.append(roc_fold_data)
    
    # Save model for this fold
    model_filename = f'cv_results/models/hybrid_ternary_fold_{fold_no}.h5'
    model.save(model_filename)
    print(f"   💾 Model saved: {model_filename}")
    
    # ==================== LOG TRAINING HISTORY ====================
    # Log detailed training history for this fold
    fold_training_log = {
        'fold': fold_no,
        'epochs_completed': len(history.history['loss']),
        'final_train_loss': history.history['loss'][-1],
        'final_train_accuracy': history.history['accuracy'][-1], 
        'final_val_loss': history.history['val_loss'][-1],
        'final_val_accuracy': history.history['val_accuracy'][-1],
        'best_val_accuracy': max(history.history['val_accuracy']),
        'best_val_accuracy_epoch': np.argmax(history.history['val_accuracy']) + 1,
        'min_val_loss': min(history.history['val_loss']),
        'min_val_loss_epoch': np.argmin(history.history['val_loss']) + 1,
        'overfitting_gap': history.history['accuracy'][-1] - history.history['val_accuracy'][-1],
        'early_stopped': len(history.history['loss']) < 20,
        'training_time': training_time,
        'classification_type': 'ternary',
        'num_classes': 3,
        'class_0_count': class_counts[0],
        'class_1_count': class_counts[1], 
        'class_2_count': class_counts[2],
        'convergence_speed': np.argmax(history.history['val_accuracy']) + 1,
        'precision_class_0': precision_per_class[0],
        'precision_class_1': precision_per_class[1],
        'precision_class_2': precision_per_class[2],
        'recall_class_0': recall_per_class[0],
        'recall_class_1': recall_per_class[1],
        'recall_class_2': recall_per_class[2],
        'f1_class_0': f1_per_class[0],
        'f1_class_1': f1_per_class[1],
        'f1_class_2': f1_per_class[2],
        'auc_class_0': auc_per_class[0],
        'auc_class_1': auc_per_class[1],
        'auc_class_2': auc_per_class[2]
    }
    training_logs.append(fold_training_log)
    
    # Save individual fold detailed history to CSV
    fold_history_data = []
    for epoch_idx in range(len(history.history['loss'])):
        epoch_record = {
            'fold': fold_no,
            'epoch': epoch_idx + 1,
            'train_loss': history.history['loss'][epoch_idx],
            'train_accuracy': history.history['accuracy'][epoch_idx],
            'val_loss': history.history['val_loss'][epoch_idx],
            'val_accuracy': history.history['val_accuracy'][epoch_idx],
            'classification_type': 'ternary',
            'num_classes': 3,
            'learning_rate': 0.001
        }
        fold_history_data.append(epoch_record)
    
    # Save individual fold history
    fold_history_df = pd.DataFrame(fold_history_data)
    fold_history_filename = f'cv_results/training_logs/fold_{fold_no}_detailed_history.csv'
    fold_history_df.to_csv(fold_history_filename, index=False)
    
    # Create epoch-by-epoch data for this fold (for aggregated file)
    for epoch_idx in range(len(history.history['loss'])):
        epoch_data = {
            'fold': fold_no,
            'epoch': epoch_idx + 1,
            'train_loss': history.history['loss'][epoch_idx],
            'train_accuracy': history.history['accuracy'][epoch_idx],
            'val_loss': history.history['val_loss'][epoch_idx],
            'val_accuracy': history.history['val_accuracy'][epoch_idx],
            'learning_rate': 0.001,  # Adam default
            'classification_type': 'ternary',
            'num_classes': 3
        }
        epoch_by_epoch_data.append(epoch_data)
    
    print(f"   📝 Training log saved: {fold_history_filename}")
    print(f"   Accuracy: {val_accuracy:.4f} | AUC (Macro): {auc_macro:.4f} | F1 (Macro): {f1_macro:.4f} | Time: {training_time:.1f}s")
    print(f"   Per-class F1: {f1_per_class}")
# Out:
# Starting 10-Fold Cross Validation for Ternary Classification...
# ============================================================
#
# 🔄 Processing Fold 1/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.5933 - loss: 0.8358 - val_accuracy: 0.3333 - val_loss: 2.9225
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 976ms/step - accuracy: 0.6972 - loss: 0.6144 - val_accuracy: 0.3889 - val_loss: 2.3083
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 986ms/step - accuracy: 0.8164 - loss: 0.4678 - val_accuracy: 0.5185 - val_loss: 1.6996
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8617 - loss: 0.3551 - val_accuracy: 0.5741 - val_loss: 1.3446
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8385 - loss: 0.4112 - val_accuracy: 0.7222 - val_loss: 0.7521
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 999ms/step - accuracy: 0.8069 - loss: 0.4796 - val_accuracy: 0.8148 - val_loss: 0.4500
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8856 - loss: 0.3165 - val_accuracy: 0.7222 - val_loss: 0.6764
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8871 - loss: 0.3256 - val_accuracy: 0.9259 - val_loss: 0.3162
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9003 - loss: 0.2674 - val_accuracy: 0.7778 - val_loss: 0.5202
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8725 - loss: 0.3285 - val_accuracy: 0.7778 - val_loss: 0.5981
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8724 - loss: 0.3184 - val_accuracy: 0.9074 - val_loss: 0.3669
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9026 - loss: 0.2900 - val_accuracy: 0.7593 - val_loss: 0.6064
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8887 - loss: 0.2884 - val_accuracy: 0.7407 - val_loss: 0.5462
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 994ms/step - accuracy: 0.8738 - loss: 0.3198 - val_accuracy: 0.7407 - val_loss: 0.5956
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8628 - loss: 0.3217 - val_accuracy: 0.8333 - val_loss: 0.3874
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 995ms/step - accuracy: 0.9210 - loss: 0.1925 - val_accuracy: 0.9074 - val_loss: 0.2321
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9253 - loss: 0.2101 - val_accuracy: 0.9630 - val_loss: 0.1929
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9329 - loss: 0.1974 - val_accuracy: 0.9630 - val_loss: 0.1725
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8876 - loss: 0.3637 - val_accuracy: 0.9630 - val_loss: 0.1565
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 997ms/step - accuracy: 0.9210 - loss: 0.2487 - val_accuracy: 0.9259 - val_loss: 0.2178
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_1.h5
#    📝 Training log saved: cv_results/training_logs/fold_1_detailed_history.csv
#    Accuracy: 0.9259 | AUC (Macro): 0.9805 | F1 (Macro): 0.9250 | Time: 347.3s
#    Per-class F1: [0.9   0.875 1.   ]
#
# 🔄 Processing Fold 2/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5340 - loss: 0.8606 - val_accuracy: 0.3333 - val_loss: 2.4839
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 968ms/step - accuracy: 0.7304 - loss: 0.5971 - val_accuracy: 0.4074 - val_loss: 2.1050
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 969ms/step - accuracy: 0.7742 - loss: 0.5513 - val_accuracy: 0.4074 - val_loss: 1.7466
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 961ms/step - accuracy: 0.8328 - loss: 0.4251 - val_accuracy: 0.5741 - val_loss: 1.1175
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 973ms/step - accuracy: 0.8503 - loss: 0.4008 - val_accuracy: 0.7778 - val_loss: 0.5211
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 981ms/step - accuracy: 0.8724 - loss: 0.3517 - val_accuracy: 0.7222 - val_loss: 0.5150
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.8489 - loss: 0.3712 - val_accuracy: 0.7593 - val_loss: 0.6138
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 971ms/step - accuracy: 0.7501 - loss: 0.5462 - val_accuracy: 0.8333 - val_loss: 0.4492
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 990ms/step - accuracy: 0.8610 - loss: 0.3593 - val_accuracy: 0.7778 - val_loss: 0.4656
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8969 - loss: 0.2813 - val_accuracy: 0.8889 - val_loss: 0.3023
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.8698 - loss: 0.3322 - val_accuracy: 0.9074 - val_loss: 0.2906
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 977ms/step - accuracy: 0.9009 - loss: 0.2993 - val_accuracy: 0.7963 - val_loss: 0.5830
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 979ms/step - accuracy: 0.8766 - loss: 0.3280 - val_accuracy: 0.8704 - val_loss: 0.3570
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 960ms/step - accuracy: 0.8642 - loss: 0.3061 - val_accuracy: 0.8333 - val_loss: 0.2749
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 965ms/step - accuracy: 0.8835 - loss: 0.2953 - val_accuracy: 0.9074 - val_loss: 0.2162
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 967ms/step - accuracy: 0.9250 - loss: 0.1981 - val_accuracy: 0.8333 - val_loss: 0.4210
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 966ms/step - accuracy: 0.9332 - loss: 0.2061 - val_accuracy: 0.9444 - val_loss: 0.2128
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9274 - loss: 0.2172 - val_accuracy: 0.9074 - val_loss: 0.2481
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 982ms/step - accuracy: 0.9203 - loss: 0.2339 - val_accuracy: 0.8704 - val_loss: 0.3314
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 978ms/step - accuracy: 0.9117 - loss: 0.2590 - val_accuracy: 0.9444 - val_loss: 0.2092
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_2.h5
#    📝 Training log saved: cv_results/training_logs/fold_2_detailed_history.csv
#    Accuracy: 0.9444 | AUC (Macro): 0.9907 | F1 (Macro): 0.9444 | Time: 337.0s
#    Per-class F1: [0.91891892 0.91428571 1.        ]
#
# 🔄 Processing Fold 3/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 997ms/step - accuracy: 0.5979 - loss: 0.8262 - val_accuracy: 0.3333 - val_loss: 2.9910
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 966ms/step - accuracy: 0.7363 - loss: 0.5606 - val_accuracy: 0.3519 - val_loss: 2.7799
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 976ms/step - accuracy: 0.7757 - loss: 0.5047 - val_accuracy: 0.3704 - val_loss: 2.4058
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 984ms/step - accuracy: 0.8131 - loss: 0.4628 - val_accuracy: 0.5000 - val_loss: 1.6923
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 979ms/step - accuracy: 0.7898 - loss: 0.4695 - val_accuracy: 0.6296 - val_loss: 0.9459
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 980ms/step - accuracy: 0.8731 - loss: 0.3568 - val_accuracy: 0.7407 - val_loss: 0.8443
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 981ms/step - accuracy: 0.8704 - loss: 0.3199 - val_accuracy: 0.7407 - val_loss: 0.6591
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 978ms/step - accuracy: 0.8521 - loss: 0.4031 - val_accuracy: 0.7963 - val_loss: 0.5932
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 986ms/step - accuracy: 0.8833 - loss: 0.3062 - val_accuracy: 0.7778 - val_loss: 0.6141
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 979ms/step - accuracy: 0.8708 - loss: 0.3371 - val_accuracy: 0.8519 - val_loss: 0.4748
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 980ms/step - accuracy: 0.8991 - loss: 0.2481 - val_accuracy: 0.7407 - val_loss: 0.6695
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.9063 - loss: 0.2433 - val_accuracy: 0.7407 - val_loss: 0.6379
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 978ms/step - accuracy: 0.8911 - loss: 0.2398 - val_accuracy: 0.8333 - val_loss: 0.6045
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 989ms/step - accuracy: 0.9329 - loss: 0.1869 - val_accuracy: 0.7963 - val_loss: 0.7362
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 980ms/step - accuracy: 0.9272 - loss: 0.1696 - val_accuracy: 0.8519 - val_loss: 0.5886
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 989ms/step - accuracy: 0.9195 - loss: 0.2315 - val_accuracy: 0.8333 - val_loss: 0.4470
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 972ms/step - accuracy: 0.9277 - loss: 0.1963 - val_accuracy: 0.8889 - val_loss: 0.4906
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 997ms/step - accuracy: 0.9568 - loss: 0.1427 - val_accuracy: 0.9259 - val_loss: 0.3176
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 983ms/step - accuracy: 0.9633 - loss: 0.1373 - val_accuracy: 0.9074 - val_loss: 0.4552
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 963ms/step - accuracy: 0.9388 - loss: 0.2512 - val_accuracy: 0.9074 - val_loss: 0.3465
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002867890DA80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002867890DA80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002867890DA80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002867890DA80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_3.h5
#    📝 Training log saved: cv_results/training_logs/fold_3_detailed_history.csv
#    Accuracy: 0.9074 | AUC (Macro): 0.9624 | F1 (Macro): 0.9071 | Time: 337.5s
#    Per-class F1: [0.90909091 0.86486486 0.94736842]
#
# 🔄 Processing Fold 4/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5766 - loss: 0.8250 - val_accuracy: 0.3333 - val_loss: 2.5994
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 969ms/step - accuracy: 0.7819 - loss: 0.5605 - val_accuracy: 0.3333 - val_loss: 2.1530
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 968ms/step - accuracy: 0.7421 - loss: 0.5953 - val_accuracy: 0.4815 - val_loss: 1.3435
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 996ms/step - accuracy: 0.8383 - loss: 0.3850 - val_accuracy: 0.7037 - val_loss: 0.7416
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 989ms/step - accuracy: 0.8040 - loss: 0.4511 - val_accuracy: 0.7407 - val_loss: 0.5335
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8392 - loss: 0.3717 - val_accuracy: 0.8148 - val_loss: 0.4272
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9017 - loss: 0.3035 - val_accuracy: 0.7963 - val_loss: 0.5078
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 997ms/step - accuracy: 0.8953 - loss: 0.2899 - val_accuracy: 0.8889 - val_loss: 0.3296
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 995ms/step - accuracy: 0.8388 - loss: 0.3716 - val_accuracy: 0.9074 - val_loss: 0.2773
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 994ms/step - accuracy: 0.8849 - loss: 0.3150 - val_accuracy: 0.9074 - val_loss: 0.2869
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8887 - loss: 0.3192 - val_accuracy: 0.8519 - val_loss: 0.2762
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 999ms/step - accuracy: 0.8953 - loss: 0.2595 - val_accuracy: 0.8519 - val_loss: 0.4753
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 995ms/step - accuracy: 0.8562 - loss: 0.3894 - val_accuracy: 0.8333 - val_loss: 0.3380
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8800 - loss: 0.3098 - val_accuracy: 0.8889 - val_loss: 0.2790
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 989ms/step - accuracy: 0.9141 - loss: 0.2275 - val_accuracy: 0.9259 - val_loss: 0.2863
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9159 - loss: 0.2749 - val_accuracy: 0.8519 - val_loss: 0.2970
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 981ms/step - accuracy: 0.8875 - loss: 0.2879 - val_accuracy: 0.8333 - val_loss: 0.3746
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 993ms/step - accuracy: 0.8643 - loss: 0.3612 - val_accuracy: 0.8333 - val_loss: 0.4117
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 995ms/step - accuracy: 0.9169 - loss: 0.2256 - val_accuracy: 0.8889 - val_loss: 0.3524
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 997ms/step - accuracy: 0.8995 - loss: 0.2697 - val_accuracy: 0.9074 - val_loss: 0.2558
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_4.h5
#    📝 Training log saved: cv_results/training_logs/fold_4_detailed_history.csv
#    Accuracy: 0.9074 | AUC (Macro): 0.9851 | F1 (Macro): 0.9084 | Time: 342.6s
#    Per-class F1: [0.88888889 0.86486486 0.97142857]
#
# 🔄 Processing Fold 5/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5365 - loss: 0.8779 - val_accuracy: 0.3333 - val_loss: 2.3902
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 971ms/step - accuracy: 0.7059 - loss: 0.6306 - val_accuracy: 0.3333 - val_loss: 2.0821
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 969ms/step - accuracy: 0.7597 - loss: 0.5254 - val_accuracy: 0.4074 - val_loss: 1.8162
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 977ms/step - accuracy: 0.7907 - loss: 0.4394 - val_accuracy: 0.5556 - val_loss: 1.8062
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.8610 - loss: 0.3713 - val_accuracy: 0.6667 - val_loss: 0.8948
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 980ms/step - accuracy: 0.7659 - loss: 0.5116 - val_accuracy: 0.6667 - val_loss: 0.9367
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 980ms/step - accuracy: 0.8196 - loss: 0.4032 - val_accuracy: 0.8148 - val_loss: 0.5294
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 978ms/step - accuracy: 0.8691 - loss: 0.3592 - val_accuracy: 0.8148 - val_loss: 0.3908
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 976ms/step - accuracy: 0.9237 - loss: 0.2428 - val_accuracy: 0.8148 - val_loss: 0.4118
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 977ms/step - accuracy: 0.9074 - loss: 0.2576 - val_accuracy: 0.9259 - val_loss: 0.2286
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 974ms/step - accuracy: 0.8812 - loss: 0.3551 - val_accuracy: 0.7778 - val_loss: 0.4804
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 967ms/step - accuracy: 0.8665 - loss: 0.3171 - val_accuracy: 0.7593 - val_loss: 0.4818
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.8936 - loss: 0.2979 - val_accuracy: 0.8148 - val_loss: 0.4434
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 971ms/step - accuracy: 0.8966 - loss: 0.2981 - val_accuracy: 0.7963 - val_loss: 0.4999
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 958ms/step - accuracy: 0.8215 - loss: 0.4142 - val_accuracy: 0.9630 - val_loss: 0.2354
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 961ms/step - accuracy: 0.8985 - loss: 0.2903 - val_accuracy: 0.9074 - val_loss: 0.2268
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 966ms/step - accuracy: 0.8640 - loss: 0.2967 - val_accuracy: 0.9444 - val_loss: 0.1814
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 969ms/step - accuracy: 0.8911 - loss: 0.2719 - val_accuracy: 0.9444 - val_loss: 0.1865
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 973ms/step - accuracy: 0.8865 - loss: 0.2462 - val_accuracy: 0.9259 - val_loss: 0.3000
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 973ms/step - accuracy: 0.8706 - loss: 0.3783 - val_accuracy: 0.8889 - val_loss: 0.3777
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_5.h5
#    📝 Training log saved: cv_results/training_logs/fold_5_detailed_history.csv
#    Accuracy: 0.8889 | AUC (Macro): 0.9774 | F1 (Macro): 0.8876 | Time: 335.5s
#    Per-class F1: [0.9        0.84848485 0.91428571]
#
# 🔄 Processing Fold 6/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6340 - loss: 0.8156 - val_accuracy: 0.3333 - val_loss: 2.8543
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 977ms/step - accuracy: 0.7883 - loss: 0.4863 - val_accuracy: 0.3704 - val_loss: 2.7015
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 972ms/step - accuracy: 0.8232 - loss: 0.4680 - val_accuracy: 0.4259 - val_loss: 1.5279
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.8186 - loss: 0.4378 - val_accuracy: 0.6481 - val_loss: 0.8758
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 978ms/step - accuracy: 0.8542 - loss: 0.3763 - val_accuracy: 0.6667 - val_loss: 0.5899
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 974ms/step - accuracy: 0.8451 - loss: 0.3658 - val_accuracy: 0.8704 - val_loss: 0.3179
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 987ms/step - accuracy: 0.8434 - loss: 0.4089 - val_accuracy: 0.8519 - val_loss: 0.3598
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 989ms/step - accuracy: 0.8793 - loss: 0.3021 - val_accuracy: 0.8333 - val_loss: 0.3279
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 986ms/step - accuracy: 0.8995 - loss: 0.2962 - val_accuracy: 0.9074 - val_loss: 0.1903
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8727 - loss: 0.3261 - val_accuracy: 0.9074 - val_loss: 0.2396
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 977ms/step - accuracy: 0.8693 - loss: 0.3367 - val_accuracy: 0.8889 - val_loss: 0.2239
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 993ms/step - accuracy: 0.8709 - loss: 0.2780 - val_accuracy: 0.8704 - val_loss: 0.2355
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 984ms/step - accuracy: 0.9619 - loss: 0.1497 - val_accuracy: 0.8889 - val_loss: 0.4055
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 975ms/step - accuracy: 0.8054 - loss: 0.5314 - val_accuracy: 0.8519 - val_loss: 0.3402
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 984ms/step - accuracy: 0.8274 - loss: 0.3690 - val_accuracy: 0.9259 - val_loss: 0.2032
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 982ms/step - accuracy: 0.8439 - loss: 0.3560 - val_accuracy: 0.8889 - val_loss: 0.2205
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 979ms/step - accuracy: 0.8786 - loss: 0.2819 - val_accuracy: 0.9074 - val_loss: 0.2008
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 981ms/step - accuracy: 0.8547 - loss: 0.3335 - val_accuracy: 0.9259 - val_loss: 0.1754
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 982ms/step - accuracy: 0.8824 - loss: 0.2785 - val_accuracy: 0.9815 - val_loss: 0.1404
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 980ms/step - accuracy: 0.9000 - loss: 0.2737 - val_accuracy: 0.8519 - val_loss: 0.5633
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_6.h5
#    📝 Training log saved: cv_results/training_logs/fold_6_detailed_history.csv
#    Accuracy: 0.8519 | AUC (Macro): 0.9223 | F1 (Macro): 0.8442 | Time: 338.2s
#    Per-class F1: [0.81818182 0.71428571 1.        ]
#
# 🔄 Processing Fold 7/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6004 - loss: 0.8431 - val_accuracy: 0.3333 - val_loss: 2.7076
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.7510 - loss: 0.5494 - val_accuracy: 0.3333 - val_loss: 2.6443
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.7907 - loss: 0.4456 - val_accuracy: 0.4259 - val_loss: 2.2540
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8428 - loss: 0.3826 - val_accuracy: 0.5185 - val_loss: 1.7056
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8019 - loss: 0.4664 - val_accuracy: 0.5926 - val_loss: 1.4742
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8580 - loss: 0.3834 - val_accuracy: 0.6111 - val_loss: 0.9660
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 999ms/step - accuracy: 0.8974 - loss: 0.3139 - val_accuracy: 0.7778 - val_loss: 0.6811
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8465 - loss: 0.3695 - val_accuracy: 0.7963 - val_loss: 0.4402
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8648 - loss: 0.3053 - val_accuracy: 0.9259 - val_loss: 0.2251
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9038 - loss: 0.2753 - val_accuracy: 0.7407 - val_loss: 0.5667
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8158 - loss: 0.4015 - val_accuracy: 0.8519 - val_loss: 0.3659
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8755 - loss: 0.3389 - val_accuracy: 0.9074 - val_loss: 0.2054
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8731 - loss: 0.3474 - val_accuracy: 0.7963 - val_loss: 0.5655
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9141 - loss: 0.2368 - val_accuracy: 0.9630 - val_loss: 0.1486
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9304 - loss: 0.1951 - val_accuracy: 0.9074 - val_loss: 0.2472
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8958 - loss: 0.2719 - val_accuracy: 0.7778 - val_loss: 0.3974
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8708 - loss: 0.3200 - val_accuracy: 0.8519 - val_loss: 0.2964
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9034 - loss: 0.3043 - val_accuracy: 0.8889 - val_loss: 0.3634
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9217 - loss: 0.2045 - val_accuracy: 0.8889 - val_loss: 0.2047
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8880 - loss: 0.2734 - val_accuracy: 0.8889 - val_loss: 0.2566
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_7.h5
#    📝 Training log saved: cv_results/training_logs/fold_7_detailed_history.csv
#    Accuracy: 0.8889 | AUC (Macro): 0.9727 | F1 (Macro): 0.8899 | Time: 351.9s
#    Per-class F1: [0.86486486 0.83333333 0.97142857]
#
# 🔄 Processing Fold 8/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.5834 - loss: 0.8572 - val_accuracy: 0.3333 - val_loss: 2.5316
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7472 - loss: 0.5837 - val_accuracy: 0.4259 - val_loss: 1.9932
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.7817 - loss: 0.5514 - val_accuracy: 0.4444 - val_loss: 1.5707
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8664 - loss: 0.4072 - val_accuracy: 0.5185 - val_loss: 1.2240
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8730 - loss: 0.3396 - val_accuracy: 0.8519 - val_loss: 0.5477
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8289 - loss: 0.4058 - val_accuracy: 0.6667 - val_loss: 0.9404
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8202 - loss: 0.4470 - val_accuracy: 0.6481 - val_loss: 0.7199
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8881 - loss: 0.3244 - val_accuracy: 0.6852 - val_loss: 0.8480
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7797 - loss: 0.5514 - val_accuracy: 0.8333 - val_loss: 0.3497
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7931 - loss: 0.4161 - val_accuracy: 0.8889 - val_loss: 0.3236
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8557 - loss: 0.3495 - val_accuracy: 0.8148 - val_loss: 0.4144
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8901 - loss: 0.3136 - val_accuracy: 0.8889 - val_loss: 0.2764
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8993 - loss: 0.2774 - val_accuracy: 0.9074 - val_loss: 0.3193
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9300 - loss: 0.2522 - val_accuracy: 0.6667 - val_loss: 0.9008
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 936ms/step - accuracy: 0.8435 - loss: 0.3904 - val_accuracy: 0.7963 - val_loss: 0.4356
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 921ms/step - accuracy: 0.9124 - loss: 0.2789 - val_accuracy: 0.9074 - val_loss: 0.2546
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 920ms/step - accuracy: 0.8882 - loss: 0.3208 - val_accuracy: 0.8519 - val_loss: 0.3412
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 927ms/step - accuracy: 0.9177 - loss: 0.2473 - val_accuracy: 0.8704 - val_loss: 0.4307
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 924ms/step - accuracy: 0.9289 - loss: 0.2249 - val_accuracy: 0.7593 - val_loss: 0.4592
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 956ms/step - accuracy: 0.9530 - loss: 0.1622 - val_accuracy: 0.9444 - val_loss: 0.2143
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_8.h5
#    📝 Training log saved: cv_results/training_logs/fold_8_detailed_history.csv
#    Accuracy: 0.9444 | AUC (Macro): 0.9841 | F1 (Macro): 0.9452 | Time: 365.5s
#    Per-class F1: [0.97142857 0.92307692 0.94117647]
#
# 🔄 Processing Fold 9/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.5927 - loss: 0.8253 - val_accuracy: 0.3333 - val_loss: 2.8713
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7692 - loss: 0.5527 - val_accuracy: 0.3519 - val_loss: 2.4822
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8004 - loss: 0.4738 - val_accuracy: 0.3704 - val_loss: 2.2140
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7790 - loss: 0.4807 - val_accuracy: 0.4444 - val_loss: 1.5934
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8227 - loss: 0.4128 - val_accuracy: 0.6481 - val_loss: 0.8364
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8570 - loss: 0.4097 - val_accuracy: 0.7037 - val_loss: 0.8136
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8416 - loss: 0.3890 - val_accuracy: 0.7593 - val_loss: 0.6530
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8509 - loss: 0.4084 - val_accuracy: 0.7222 - val_loss: 0.7895
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8820 - loss: 0.2978 - val_accuracy: 0.7593 - val_loss: 0.7439
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8847 - loss: 0.2992 - val_accuracy: 0.7778 - val_loss: 0.5037
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8856 - loss: 0.3033 - val_accuracy: 0.7963 - val_loss: 0.5016
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8092 - loss: 0.3561 - val_accuracy: 0.8148 - val_loss: 0.3515
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8668 - loss: 0.3107 - val_accuracy: 0.8519 - val_loss: 0.4695
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9028 - loss: 0.2598 - val_accuracy: 0.8148 - val_loss: 0.4462
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8738 - loss: 0.2964 - val_accuracy: 0.9074 - val_loss: 0.3363
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9130 - loss: 0.2466 - val_accuracy: 0.9074 - val_loss: 0.2417
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9011 - loss: 0.2786 - val_accuracy: 0.8704 - val_loss: 0.3162
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9338 - loss: 0.2172 - val_accuracy: 0.8519 - val_loss: 0.4495
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9189 - loss: 0.1932 - val_accuracy: 0.8889 - val_loss: 0.3273
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9032 - loss: 0.2709 - val_accuracy: 0.8889 - val_loss: 0.2804
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_9.h5
#    📝 Training log saved: cv_results/training_logs/fold_9_detailed_history.csv
#    Accuracy: 0.8889 | AUC (Macro): 0.9877 | F1 (Macro): 0.8871 | Time: 417.6s
#    Per-class F1: [0.87804878 0.83870968 0.94444444]
#
# 🔄 Processing Fold 10/10
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.5394 - loss: 0.8609 - val_accuracy: 0.3333 - val_loss: 2.7334
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.7168 - loss: 0.6288 - val_accuracy: 0.3519 - val_loss: 2.4901
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.7872 - loss: 0.5250 - val_accuracy: 0.4074 - val_loss: 2.3391
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8113 - loss: 0.4221 - val_accuracy: 0.4815 - val_loss: 1.4211
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7981 - loss: 0.4331 - val_accuracy: 0.5556 - val_loss: 1.1379
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8806 - loss: 0.3357 - val_accuracy: 0.7963 - val_loss: 0.4351
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7963 - loss: 0.5650 - val_accuracy: 0.6481 - val_loss: 0.7701
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8676 - loss: 0.3243 - val_accuracy: 0.6296 - val_loss: 0.9314
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8748 - loss: 0.3284 - val_accuracy: 0.6852 - val_loss: 0.7348
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8855 - loss: 0.3243 - val_accuracy: 0.7593 - val_loss: 0.6067
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8972 - loss: 0.2642 - val_accuracy: 0.8519 - val_loss: 0.4744
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8926 - loss: 0.2811 - val_accuracy: 0.7963 - val_loss: 0.5345
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8816 - loss: 0.3190 - val_accuracy: 0.7407 - val_loss: 0.7257
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8879 - loss: 0.3004 - val_accuracy: 0.8519 - val_loss: 0.3555
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8990 - loss: 0.2773 - val_accuracy: 0.8148 - val_loss: 0.4085
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8903 - loss: 0.2508 - val_accuracy: 0.8148 - val_loss: 0.3559
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9472 - loss: 0.1914 - val_accuracy: 0.9074 - val_loss: 0.2710
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9495 - loss: 0.1706 - val_accuracy: 0.9074 - val_loss: 0.2481
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9520 - loss: 0.1646 - val_accuracy: 0.9259 - val_loss: 0.2559
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9539 - loss: 0.1540 - val_accuracy: 0.9259 - val_loss: 0.2368
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#    💾 Model saved: cv_results/models/hybrid_ternary_fold_10.h5
#    📝 Training log saved: cv_results/training_logs/fold_10_detailed_history.csv
#    Accuracy: 0.9259 | AUC (Macro): 0.9815 | F1 (Macro): 0.9259 | Time: 389.8s
#    Per-class F1: [0.91891892 0.91428571 0.94444444]

# %%
# Convert to DataFrame
df_results = pd.DataFrame(fold_results)
df_results.to_csv('cv_results/ternary_results.csv', index=False)

# ==================== SAVE TRAINING LOGS ====================
# Save detailed training logs
df_training_logs = pd.DataFrame(training_logs)
df_training_logs.to_csv('cv_results/training_logs/fold_training_summary.csv', index=False)

# Save epoch-by-epoch data
df_epoch_data = pd.DataFrame(epoch_by_epoch_data)
df_epoch_data.to_csv('cv_results/training_logs/epoch_by_epoch_history.csv', index=False)

# Save aggregated training statistics to CSV
training_stats_data = []
training_stats_data.append({
    'metric': 'classification_type',
    'value': 'ternary',
    'description': 'Type of classification'
})
training_stats_data.append({
    'metric': 'num_classes', 
    'value': 3,
    'description': 'Number of classes'
})
training_stats_data.append({
    'metric': 'total_folds',
    'value': len(training_logs),
    'description': 'Total number of folds'
})
training_stats_data.append({
    'metric': 'avg_epochs_completed',
    'value': df_training_logs['epochs_completed'].mean(),
    'description': 'Average epochs completed across folds'
})
training_stats_data.append({
    'metric': 'avg_training_time',
    'value': df_training_logs['training_time'].mean(),
    'description': 'Average training time in seconds'
})
training_stats_data.append({
    'metric': 'avg_final_train_acc',
    'value': df_training_logs['final_train_accuracy'].mean(),
    'description': 'Average final training accuracy'
})
training_stats_data.append({
    'metric': 'avg_final_val_acc',
    'value': df_training_logs['final_val_accuracy'].mean(),
    'description': 'Average final validation accuracy'
})
training_stats_data.append({
    'metric': 'avg_best_val_acc',
    'value': df_training_logs['best_val_accuracy'].mean(),
    'description': 'Average best validation accuracy'
})
training_stats_data.append({
    'metric': 'avg_overfitting_gap',
    'value': df_training_logs['overfitting_gap'].mean(),
    'description': 'Average overfitting gap'
})
training_stats_data.append({
    'metric': 'early_stopped_folds',
    'value': df_training_logs['early_stopped'].sum(),
    'description': 'Number of folds that stopped early'
})
training_stats_data.append({
    'metric': 'avg_convergence_speed',
    'value': df_training_logs['convergence_speed'].mean(),
    'description': 'Average epoch of best validation accuracy'
})

# Add convergence analysis
fastest_convergence_idx = df_training_logs['best_val_accuracy_epoch'].idxmin()
slowest_convergence_idx = df_training_logs['best_val_accuracy_epoch'].idxmax()
most_overfitted_idx = df_training_logs['overfitting_gap'].idxmax()
least_overfitted_idx = df_training_logs['overfitting_gap'].idxmin()
best_performer_idx = df_training_logs['best_val_accuracy'].idxmax()
worst_performer_idx = df_training_logs['best_val_accuracy'].idxmin()

convergence_analysis_data = [
    {
        'analysis_type': 'fastest_convergence',
        'fold': df_training_logs.iloc[fastest_convergence_idx]['fold'],
        'metric_value': df_training_logs.iloc[fastest_convergence_idx]['best_val_accuracy_epoch'],
        'description': 'Fold with fastest convergence (lowest epoch for best val acc)'
    },
    {
        'analysis_type': 'slowest_convergence', 
        'fold': df_training_logs.iloc[slowest_convergence_idx]['fold'],
        'metric_value': df_training_logs.iloc[slowest_convergence_idx]['best_val_accuracy_epoch'],
        'description': 'Fold with slowest convergence (highest epoch for best val acc)'
    },
    {
        'analysis_type': 'most_overfitted',
        'fold': df_training_logs.iloc[most_overfitted_idx]['fold'],
        'metric_value': df_training_logs.iloc[most_overfitted_idx]['overfitting_gap'],
        'description': 'Fold with highest overfitting gap'
    },
    {
        'analysis_type': 'least_overfitted',
        'fold': df_training_logs.iloc[least_overfitted_idx]['fold'], 
        'metric_value': df_training_logs.iloc[least_overfitted_idx]['overfitting_gap'],
        'description': 'Fold with lowest overfitting gap'
    },
    {
        'analysis_type': 'best_performer',
        'fold': df_training_logs.iloc[best_performer_idx]['fold'],
        'metric_value': df_training_logs.iloc[best_performer_idx]['best_val_accuracy'],
        'description': 'Fold with highest validation accuracy'
    },
    {
        'analysis_type': 'worst_performer',
        'fold': df_training_logs.iloc[worst_performer_idx]['fold'],
        'metric_value': df_training_logs.iloc[worst_performer_idx]['best_val_accuracy'],
        'description': 'Fold with lowest validation accuracy'
    }
]

# Class balance analysis
class_balance_data = []
for i in range(3):
    class_balance_data.append({
        'class_name': class_names[i],
        'class_index': i,
        'avg_samples': df_training_logs[f'class_{i}_count'].mean(),
        'std_samples': df_training_logs[f'class_{i}_count'].std(),
        'min_samples': df_training_logs[f'class_{i}_count'].min(),
        'max_samples': df_training_logs[f'class_{i}_count'].max()
    })

# Save all analysis to CSV files
df_training_stats = pd.DataFrame(training_stats_data)
df_training_stats.to_csv('cv_results/training_logs/training_statistics.csv', index=False)

df_convergence_analysis = pd.DataFrame(convergence_analysis_data)
df_convergence_analysis.to_csv('cv_results/training_logs/convergence_analysis.csv', index=False)

df_class_balance = pd.DataFrame(class_balance_data)
df_class_balance.to_csv('cv_results/training_logs/class_balance_analysis.csv', index=False)

print(f"\n📝 TRAINING LOGS SAVED:")
print(f"   - cv_results/training_logs/fold_training_summary.csv (summary per fold)")
print(f"   - cv_results/training_logs/epoch_by_epoch_history.csv (detailed epoch data)")
print(f"   - cv_results/training_logs/training_statistics.csv (aggregated stats)")
print(f"   - cv_results/training_logs/convergence_analysis.csv (convergence analysis)")
print(f"   - cv_results/training_logs/class_balance_analysis.csv (class balance info)")
print(f"   - cv_results/training_logs/fold_X_detailed_history.csv (individual fold histories)")

# Print summary
print(f"\n📊 TERNARY CLASSIFICATION RESULTS SUMMARY:")
print(f"   Accuracy:          {df_results['Val_Accuracy'].mean():.4f} ± {df_results['Val_Accuracy'].std():.4f}")
print(f"   Precision (Macro): {df_results['Precision_Macro'].mean():.4f} ± {df_results['Precision_Macro'].std():.4f}")
print(f"   Recall (Macro):    {df_results['Recall_Macro'].mean():.4f} ± {df_results['Recall_Macro'].std():.4f}")
print(f"   F1-Score (Macro):  {df_results['F1_Score_Macro'].mean():.4f} ± {df_results['F1_Score_Macro'].std():.4f}")
print(f"   AUC (Macro):       {df_results['AUC_Macro'].mean():.4f} ± {df_results['AUC_Macro'].std():.4f}")

print(f"\n📈 TRAINING SUMMARY:")
print(f"   Avg Epochs Completed: {df_training_logs['epochs_completed'].mean():.1f} ± {df_training_logs['epochs_completed'].std():.1f}")
print(f"   Avg Training Time:    {df_training_logs['training_time'].mean():.1f} ± {df_training_logs['training_time'].std():.1f} seconds")
print(f"   Early Stopped Folds:  {df_training_logs['early_stopped'].sum()}/10")
print(f"   Avg Overfitting Gap:  {df_training_logs['overfitting_gap'].mean():.4f} ± {df_training_logs['overfitting_gap'].std():.4f}")
print(f"   Best Val Acc Epoch:   {df_training_logs['best_val_accuracy_epoch'].mean():.1f} ± {df_training_logs['best_val_accuracy_epoch'].std():.1f}")

print(f"\n📊 PER-CLASS PERFORMANCE:")
for i in range(3):
    print(f"   {class_names[i]}:")
    print(f"     Precision: {df_results[f'Precision_Class_{i}'].mean():.4f} ± {df_results[f'Precision_Class_{i}'].std():.4f}")
    print(f"     Recall:    {df_results[f'Recall_Class_{i}'].mean():.4f} ± {df_results[f'Recall_Class_{i}'].std():.4f}")
    print(f"     F1-Score:  {df_results[f'F1_Class_{i}'].mean():.4f} ± {df_results[f'F1_Class_{i}'].std():.4f}")
    print(f"     AUC:       {df_results[f'AUC_Class_{i}'].mean():.4f} ± {df_results[f'AUC_Class_{i}'].std():.4f}")

# ==================== VISUALIZATIONS ====================

# 1. CONFUSION MATRIX
plt.figure(figsize=(8, 6))
sum_cm = np.sum(confusion_matrices, axis=0)
sns.heatmap(sum_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix (10-Fold CV)\nTernary Classification')
plt.xlabel('Predicted')
plt.ylabel('Actual')

# Add overall accuracy
total_samples = np.sum(sum_cm)
correct_predictions = np.trace(sum_cm)
overall_accuracy = correct_predictions / total_samples
plt.figtext(0.02, 0.02, f'Overall Accuracy: {overall_accuracy:.3f}', 
            fontsize=12, ha='left', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.savefig('cv_results/ternary_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# 2. TRAINING & VALIDATION ACCURACY
plt.figure(figsize=(10, 5))

# Calculate average accuracy across folds
max_epochs = max(len(h['accuracy']) for h in all_histories)
avg_train_acc = []
avg_val_acc = []

for epoch in range(max_epochs):
    train_accs = [h['accuracy'][epoch] for h in all_histories if len(h['accuracy']) > epoch]
    val_accs = [h['val_accuracy'][epoch] for h in all_histories if len(h['val_accuracy']) > epoch]
    avg_train_acc.append(np.mean(train_accs))
    avg_val_acc.append(np.mean(val_accs))

epochs = range(1, len(avg_train_acc) + 1)
plt.plot(epochs, avg_train_acc, 'b-', label='Training Accuracy', linewidth=2, marker='o', markersize=4)
plt.plot(epochs, avg_val_acc, 'r-', label='Validation Accuracy', linewidth=2, marker='s', markersize=4)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Average Training & Validation Accuracy\nTernary Classification')
plt.legend()
plt.grid(True, alpha=0.3)

# Add final accuracy values
final_train = avg_train_acc[-1]
final_val = avg_val_acc[-1]
plt.text(0.02, 0.98, f'Final: Train={final_train:.3f}, Val={final_val:.3f}, Gap={final_train-final_val:.3f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='top',
         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

plt.tight_layout()
plt.savefig('cv_results/ternary_accuracy_curves.png', dpi=300, bbox_inches='tight')
plt.show()

# 3. TRAINING & VALIDATION LOSS
plt.figure(figsize=(10, 5))

# Calculate average loss across folds
avg_train_loss = []
avg_val_loss = []

for epoch in range(max_epochs):
    train_losses = [h['loss'][epoch] for h in all_histories if len(h['loss']) > epoch]
    val_losses = [h['val_loss'][epoch] for h in all_histories if len(h['val_loss']) > epoch]
    avg_train_loss.append(np.mean(train_losses))
    avg_val_loss.append(np.mean(val_losses))

plt.plot(epochs, avg_train_loss, 'b-', label='Training Loss', linewidth=2, marker='o', markersize=4)
plt.plot(epochs, avg_val_loss, 'r-', label='Validation Loss', linewidth=2, marker='s', markersize=4)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Average Training & Validation Loss\nTernary Classification')
plt.legend()
plt.grid(True, alpha=0.3)

# Add final loss values
final_train_loss = avg_train_loss[-1]
final_val_loss = avg_val_loss[-1]
plt.text(0.02, 0.98, f'Final: Train={final_train_loss:.3f}, Val={final_val_loss:.3f}', 
         transform=plt.gca().transAxes, fontsize=10, verticalalignment='top',
         bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))

plt.tight_layout()
plt.savefig('cv_results/ternary_loss_curves.png', dpi=300, bbox_inches='tight')
plt.show()

# 4. ROC CURVES (One for each class)
plt.figure(figsize=(15, 5))

for class_idx in range(3):
    plt.subplot(1, 3, class_idx + 1)
    
    # Plot ROC for each fold (light lines)
    for fold_roc in all_roc_data:
        fpr = fold_roc[f'class_{class_idx}']['fpr']
        tpr = fold_roc[f'class_{class_idx}']['tpr']
        plt.plot(fpr, tpr, alpha=0.3, color='gray', linewidth=1)
    
    # Calculate and plot average ROC
    mean_fpr = np.linspace(0, 1, 100)
    tprs = []
    aucs = []
    
    for fold_roc in all_roc_data:
        fpr = fold_roc[f'class_{class_idx}']['fpr']
        tpr = fold_roc[f'class_{class_idx}']['tpr']
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        aucs.append(fold_roc[f'class_{class_idx}']['auc'])
    
    mean_tpr = np.mean(tprs, axis=0)
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    
    # Fill area under curve
    plt.fill_between(mean_fpr, mean_tpr, alpha=0.2, color='blue')
    plt.plot(mean_fpr, mean_tpr, color='blue', linewidth=3,
             label=f'Mean ROC (AUC = {mean_auc:.3f} ± {std_auc:.3f})')
    plt.plot([0, 1], [0, 1], 'k--', linewidth=1, alpha=0.8)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {class_names[class_idx]}')
    plt.legend(loc="lower right")
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('cv_results/ternary_roc_curves.png', dpi=300, bbox_inches='tight')
plt.show()

# 5. PER-CLASS PERFORMANCE COMPARISON
plt.figure(figsize=(12, 8))

# Subplot 1: Per-class F1 Scores
plt.subplot(2, 2, 1)
f1_data = [df_results[f'F1_Class_{i}'].values for i in range(3)]
box_plot = plt.boxplot(f1_data, labels=class_names, patch_artist=True)
colors = ['lightblue', 'lightgreen', 'lightcoral']
for patch, color in zip(box_plot['boxes'], colors):
    patch.set_facecolor(color)
plt.ylabel('F1 Score')
plt.title('Per-Class F1 Score Distribution')
plt.grid(True, alpha=0.3)

# Subplot 2: Per-class AUC
plt.subplot(2, 2, 2)
auc_data = [df_results[f'AUC_Class_{i}'].values for i in range(3)]
box_plot = plt.boxplot(auc_data, labels=class_names, patch_artist=True)
for patch, color in zip(box_plot['boxes'], colors):
    patch.set_facecolor(color)
plt.ylabel('AUC')
plt.title('Per-Class AUC Distribution')
plt.grid(True, alpha=0.3)

# Subplot 3: Overall metrics comparison
plt.subplot(2, 2, 3)
overall_metrics = ['Val_Accuracy', 'Precision_Macro', 'Recall_Macro', 'F1_Score_Macro', 'AUC_Macro']
overall_data = [df_results[col].values for col in overall_metrics]
box_plot = plt.boxplot(overall_data, labels=['Accuracy', 'Precision', 'Recall', 'F1', 'AUC'], patch_artist=True)
metric_colors = ['wheat', 'lightpink', 'lightgray', 'lightyellow', 'lightsteelblue']
for patch, color in zip(box_plot['boxes'], metric_colors):
    patch.set_facecolor(color)
plt.ylabel('Score')
plt.title('Overall Metrics Distribution')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)

# Subplot 4: Macro vs Weighted comparison
plt.subplot(2, 2, 4)
metrics = ['Precision', 'Recall', 'F1_Score', 'AUC']
macro_vals = [df_results[f'{m}_Macro'].mean() for m in metrics]
weighted_vals = [df_results[f'{m}_Weighted'].mean() for m in metrics]

x = np.arange(len(metrics))
width = 0.35
plt.bar(x - width/2, macro_vals, width, label='Macro', alpha=0.7, color='skyblue')
plt.bar(x + width/2, weighted_vals, width, label='Weighted', alpha=0.7, color='lightcoral')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Macro vs Weighted Averages')
plt.xticks(x, metrics)
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('cv_results/ternary_performance_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# ==================== MODEL SELECTION ====================

print(f"\n🎯 MODEL SELECTION ANALYSIS:")

# Best model by different criteria
best_acc_idx = df_results['Val_Accuracy'].idxmax()
best_auc_idx = df_results['AUC_Macro'].idxmax()
best_f1_idx = df_results['F1_Score_Macro'].idxmax()

print(f"   Best Accuracy:  Fold {df_results.iloc[best_acc_idx]['Fold']} ({df_results.iloc[best_acc_idx]['Val_Accuracy']:.4f})")
print(f"   Best AUC:       Fold {df_results.iloc[best_auc_idx]['Fold']} ({df_results.iloc[best_auc_idx]['AUC_Macro']:.4f})")
print(f"   Best F1-Score:  Fold {df_results.iloc[best_f1_idx]['Fold']} ({df_results.iloc[best_f1_idx]['F1_Score_Macro']:.4f})")

# Most consistent models
acc_mean = df_results['Val_Accuracy'].mean()
acc_std = df_results['Val_Accuracy'].std()
consistent_models = df_results[df_results['Val_Accuracy'] > (acc_mean - acc_std/2)]
print(f"   Consistent Models: {len(consistent_models)} folds with accuracy > {acc_mean - acc_std/2:.3f}")

# Class-specific best models
print(f"\n📊 BEST MODELS BY CLASS:")
for i in range(3):
    best_class_f1_idx = df_results[f'F1_Class_{i}'].idxmax()
    best_class_auc_idx = df_results[f'AUC_Class_{i}'].idxmax()
    print(f"   {class_names[i]}:")
    print(f"     Best F1:  Fold {df_results.iloc[best_class_f1_idx]['Fold']} ({df_results.iloc[best_class_f1_idx][f'F1_Class_{i}']:.4f})")
    print(f"     Best AUC: Fold {df_results.iloc[best_class_auc_idx]['Fold']} ({df_results.iloc[best_class_auc_idx][f'AUC_Class_{i}']:.4f})")

print(f"\n💾 Files saved:")
print(f"   - cv_results/ternary_results.csv")
print(f"   - cv_results/models/hybrid_ternary_fold_1.h5 to hybrid_ternary_fold_10.h5 (trained models)")
print(f"   - cv_results/training_logs/fold_training_summary.csv (training summary)")
print(f"   - cv_results/training_logs/epoch_by_epoch_history.csv (detailed epoch data)")
print(f"   - cv_results/training_logs/training_statistics.csv (aggregated stats)")
print(f"   - cv_results/training_logs/convergence_analysis.csv (convergence analysis)")
print(f"   - cv_results/training_logs/class_balance_analysis.csv (class balance info)")
print(f"   - cv_results/training_logs/fold_X_detailed_history.csv (individual histories)")
print(f"   - cv_results/ternary_confusion_matrix.png")
print(f"   - cv_results/ternary_accuracy_curves.png")
print(f"   - cv_results/ternary_loss_curves.png")
print(f"   - cv_results/ternary_roc_curves.png")
print(f"   - cv_results/ternary_performance_analysis.png")

print(f"\n🔍 TRAINING LOG ANALYSIS EXAMPLES:")
print(f"   # Load epoch-by-epoch data")
print(f"   df_epochs = pd.read_csv('cv_results/training_logs/epoch_by_epoch_history.csv')")
print(f"   # Filter ternary classification data")
print(f"   ternary_epochs = df_epochs[df_epochs['classification_type'] == 'ternary']")
print(f"   # Analyze convergence for specific fold")
print(f"   fold_1_data = ternary_epochs[ternary_epochs['fold'] == 1]")
print(f"   # Load training summary for analysis")
print(f"   df_summary = pd.read_csv('cv_results/training_logs/fold_training_summary.csv')")
print(f"   # Load convergence analysis")
print(f"   df_convergence = pd.read_csv('cv_results/training_logs/convergence_analysis.csv')")
print(f"   fastest_fold = df_convergence[df_convergence['analysis_type'] == 'fastest_convergence']['fold'].iloc[0]")

print(f"\n🔍 PER-CLASS ANALYSIS EXAMPLES:")
print(f"   # Load fold training summary for per-class metrics")
print(f"   df_summary = pd.read_csv('cv_results/training_logs/fold_training_summary.csv')")
print(f"   # Analyze per-class performance across folds")
print(f"   class_0_f1 = df_summary['f1_class_0'].mean()")
print(f"   class_1_f1 = df_summary['f1_class_1'].mean()")
print(f"   class_2_f1 = df_summary['f1_class_2'].mean()")
print(f"   # Load class balance analysis")
print(f"   df_balance = pd.read_csv('cv_results/training_logs/class_balance_analysis.csv')")
print(f"   print(df_balance)")

print(f"\n🔄 Model Loading Examples:")
print(f"   from tensorflow.keras.models import load_model")
print(f"   # Load best overall model")
print(f"   best_model = load_model('cv_results/models/hybrid_ternary_fold_{df_results.iloc[best_acc_idx]['Fold']:.0f}.h5')")
print(f"   # Load best model for specific class")
print(f"   best_class0_model = load_model('cv_results/models/hybrid_ternary_fold_{df_results.iloc[best_class_f1_idx]['Fold']:.0f}.h5')")
print(f"   # Prediction for ternary classification")
print(f"   predictions = best_model.predict(new_data)")
print(f"   predicted_classes = np.argmax(predictions, axis=1)")
print(f"   # Get prediction probabilities for each class")
print(f"   class_probabilities = predictions  # Shape: (n_samples, 3)")

print(f"\n🎯 ENSEMBLE PREDICTION EXAMPLE:")
print(f"   # Load all models for ensemble")
print(f"   models = []")
print(f"   for fold in range(1, 11):")
print(f"       model = load_model(f'cv_results/models/hybrid_ternary_fold_{{fold}}.h5')")
print(f"       models.append(model)")
print(f"   # Ensemble prediction")
print(f"   ensemble_pred = np.mean([model.predict(new_data) for model in models], axis=0)")
print(f"   ensemble_classes = np.argmax(ensemble_pred, axis=1)")

print(f"\n🔍 CLASS IMBALANCE ANALYSIS:")
df_balance = pd.DataFrame(class_balance_data)
total_samples = df_balance['avg_samples'].sum()
for i, row in df_balance.iterrows():
    class_proportion = row['avg_samples'] / total_samples
    print(f"   {row['class_name']} proportion: {class_proportion:.3f} ({row['avg_samples']:.1f} ± {row['std_samples']:.1f} samples)")

print(f"\n✅ Ternary classification cross-validation completed!")
print("=" * 60)
# Out:
# 📝 TRAINING LOGS SAVED:
#    - cv_results/training_logs/fold_training_summary.csv (summary per fold)
#    - cv_results/training_logs/epoch_by_epoch_history.csv (detailed epoch data)
#    - cv_results/training_logs/training_statistics.csv (aggregated stats)
#    - cv_results/training_logs/convergence_analysis.csv (convergence analysis)
#    - cv_results/training_logs/class_balance_analysis.csv (class balance info)
#    - cv_results/training_logs/fold_X_detailed_history.csv (individual fold histories)
#
# 📊 TERNARY CLASSIFICATION RESULTS SUMMARY:
#    Accuracy:          0.9074 ± 0.0290
#    Precision (Macro): 0.9184 ± 0.0215
#    Recall (Macro):    0.9074 ± 0.0290
#    F1-Score (Macro):  0.9065 ± 0.0308
#    AUC (Macro):       0.9744 ± 0.0200
#
# 📈 TRAINING SUMMARY:
#    Avg Epochs Completed: 20.0 ± 0.0
#    Avg Training Time:    356.3 ± 27.4 seconds
#    Early Stopped Folds:  0/10
#    Avg Overfitting Gap:  -0.0014 ± 0.0289
#    Best Val Acc Epoch:   16.9 ± 2.1
#
# 📊 PER-CLASS PERFORMANCE:
#    Class_0:
#      Precision: 0.8632 ± 0.0944
#      Recall:    0.9444 ± 0.0586
#      F1-Score:  0.8968 ± 0.0399
#      AUC:       0.9721 ± 0.0218
#    Class_1:
#      Precision: 0.9190 ± 0.0698
#      Recall:    0.8222 ± 0.1223
#      F1-Score:  0.8591 ± 0.0602
#      AUC:       0.9569 ± 0.0406
#    Class_2:
#      Precision: 0.9730 ± 0.0370
#      Recall:    0.9556 ± 0.0438
#      F1-Score:  0.9635 ± 0.0299
#      AUC:       0.9943 ± 0.0094
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23524\1904621794.py:310: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box_plot = plt.boxplot(f1_data, labels=class_names, patch_artist=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23524\1904621794.py:321: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box_plot = plt.boxplot(auc_data, labels=class_names, patch_artist=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23524\1904621794.py:332: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box_plot = plt.boxplot(overall_data, labels=['Accuracy', 'Precision', 'Recall', 'F1', 'AUC'], patch_artist=True)
# 🎯 MODEL SELECTION ANALYSIS:
#    Best Accuracy:  Fold 2.0 (0.9444)
#    Best AUC:       Fold 2.0 (0.9907)
#    Best F1-Score:  Fold 8.0 (0.9452)
#    Consistent Models: 6 folds with accuracy > 0.893
#
# 📊 BEST MODELS BY CLASS:
#    Class_0:
#      Best F1:  Fold 8.0 (0.9714)
#      Best AUC: Fold 9.0 (0.9923)
#    Class_1:
#      Best F1:  Fold 8.0 (0.9231)
#      Best AUC: Fold 8.0 (0.9846)
#    Class_2:
#      Best F1:  Fold 1.0 (1.0000)
#      Best AUC: Fold 1.0 (1.0000)
#
# 💾 Files saved:
#    - cv_results/ternary_results.csv
#    - cv_results/models/hybrid_ternary_fold_1.h5 to hybrid_ternary_fold_10.h5 (trained models)
#    - cv_results/training_logs/fold_training_summary.csv (training summary)
#    - cv_results/training_logs/epoch_by_epoch_history.csv (detailed epoch data)
#    - cv_results/training_logs/training_statistics.csv (aggregated stats)
#    - cv_results/training_logs/convergence_analysis.csv (convergence analysis)
#    - cv_results/training_logs/class_balance_analysis.csv (class balance info)
#    - cv_results/training_logs/fold_X_detailed_history.csv (individual histories)
#    - cv_results/ternary_confusion_matrix.png
#    - cv_results/ternary_accuracy_curves.png
#    - cv_results/ternary_loss_curves.png
#    - cv_results/ternary_roc_curves.png
#    - cv_results/ternary_performance_analysis.png
#
# 🔍 TRAINING LOG ANALYSIS EXAMPLES:
#    # Load epoch-by-epoch data
#    df_epochs = pd.read_csv('cv_results/training_logs/epoch_by_epoch_history.csv')
#    # Filter ternary classification data
#    ternary_epochs = df_epochs[df_epochs['classification_type'] == 'ternary']
#    # Analyze convergence for specific fold
#    fold_1_data = ternary_epochs[ternary_epochs['fold'] == 1]
#    # Load training summary for analysis
#    df_summary = pd.read_csv('cv_results/training_logs/fold_training_summary.csv')
#    # Load convergence analysis
#    df_convergence = pd.read_csv('cv_results/training_logs/convergence_analysis.csv')
#    fastest_fold = df_convergence[df_convergence['analysis_type'] == 'fastest_convergence']['fold'].iloc[0]
#
# 🔍 PER-CLASS ANALYSIS EXAMPLES:
#    # Load fold training summary for per-class metrics
#    df_summary = pd.read_csv('cv_results/training_logs/fold_training_summary.csv')
#    # Analyze per-class performance across folds
#    class_0_f1 = df_summary['f1_class_0'].mean()
#    class_1_f1 = df_summary['f1_class_1'].mean()
#    class_2_f1 = df_summary['f1_class_2'].mean()
#    # Load class balance analysis
#    df_balance = pd.read_csv('cv_results/training_logs/class_balance_analysis.csv')
#    print(df_balance)
#
# 🔄 Model Loading Examples:
#    from tensorflow.keras.models import load_model
#    # Load best overall model
#    best_model = load_model('cv_results/models/hybrid_ternary_fold_2.h5')
#    # Load best model for specific class
#    best_class0_model = load_model('cv_results/models/hybrid_ternary_fold_1.h5')
#    # Prediction for ternary classification
#    predictions = best_model.predict(new_data)
#    predicted_classes = np.argmax(predictions, axis=1)
#    # Get prediction probabilities for each class
#    class_probabilities = predictions  # Shape: (n_samples, 3)
#
# 🎯 ENSEMBLE PREDICTION EXAMPLE:
#    # Load all models for ensemble
#    models = []
#    for fold in range(1, 11):
#        model = load_model(f'cv_results/models/hybrid_ternary_fold_{fold}.h5')
#        models.append(model)
#    # Ensemble prediction
#    ensemble_pred = np.mean([model.predict(new_data) for model in models], axis=0)
#    ensemble_classes = np.argmax(ensemble_pred, axis=1)
#
# 🔍 CLASS IMBALANCE ANALYSIS:
#    Class_0 proportion: 0.333 (18.0 ± 0.0 samples)
#    Class_1 proportion: 0.333 (18.0 ± 0.0 samples)
#    Class_2 proportion: 0.333 (18.0 ± 0.0 samples)
#
# ✅ Ternary classification cross-validation completed!
# ============================================================
